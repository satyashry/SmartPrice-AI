# %%
from bs4 import BeautifulSoup
import selenium
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
import time
import requests
from selenium.webdriver.chrome.options import Options



def get_page(url):
    chrome_options = Options()
    chrome_options.add_experimental_option("detach", True)# keeps the browser Active
    driver = webdriver.Chrome(options = chrome_options)# opens a empty Chrome Browser connecting with the URL
    driver.get(url)
    time.sleep(2) # Allowing time for to load
    html = driver.page_source # changes the format to HTML

    return BeautifulSoup(html, "html.parser")

soup = get_page("https://www.flipkart.com/search?q=laptops&page=1")

# %%
def scrape_page(soup):

    brand = []
    actual_price = []
    current_price = []


    # for brand
    for i in soup.find_all("div", class_ = "RG5Slk"):
        brand.append(i.text)
    # for actual prices
    for i in soup.find_all("div", class_ = "kRYCnD gxR4EY") :
        actual_price.append(i.text)
    # for discount prices
    for i in soup.find_all("div", class_ = "hZ3P6w DeU9vF"):
        current_price.append(i.text)

    return brand,actual_price,current_price

brand,actual_price,current_price = scrape_page(soup)
print(len(brand),len(actual_price),len(current_price))
# Out:
# 24 24 24

# %%
def  scrape_all_pages(total_pages):
    all_brands = []
    all_actual = []
    all_current = []

    for page in range(1,total_pages+1):
        url = f"https://www.flipkart.com/search?q=laptops&page={page}"
        soup_all = get_page(url)

        brand,actual,current = scrape_page(soup_all)
        all_brands.extend(brand)
        all_actual.extend(actual)
        all_current.extend(current)
        print(f"Scraped Page {page} ✅")
    return all_brands,all_actual,all_current

# %%
all_brands,all_actual,all_current = scrape_all_pages(2)
# Out:
# Scraped Page 1 ✅
# Scraped Page 2 ✅

# %%
len(all_brands)
# Out:
# 48

# %%
# Out:
# ['MICROSOFT Surface Pro 12" with Pen Core 8 Snapdragon X Plus - (16 GB/512 GB SSD/Windows 11 Home) EP2-2...',
#  'ASUS Intel Core i5 13th Gen 1335U - (16 GB/512 GB SSD/Windows 11 Pro) B3404CVAB-Q50884X Thin and Light...',
#  'HP Victus AI AMD Ryzen 7 Octa Core 260 - (24 GB/1 TB SSD/Windows 11 Home/8 GB Graphics/NVIDIA GeForce ...',
#  'ASUS Vivobook 15 (2025) with Office 2024 + M365 Basic* Intel Core i3 13th Gen - (8 GB/512 GB SSD/Windo...',
#  'MOTOROLA Motobook 60 Pro Full Metal OLED AI PC Intel Core Ultra 5 225H - (16 GB/512 GB SSD/Windows 11 ...',
#  'ASUS Vivobook Go 15 (2025) with Office 2024 + M365 Basic*, AMD Ryzen 5 Quad Core 7520U - (8 GB/512 GB ...',
#  'HP MS Office 2024 Intel Core i5 13th Gen 13420H - (16 GB/512 GB SSD/Windows 11 Home) 15-fr0045TU Thin ...',
#  'Lenovo IdeaPad Slim 3 with 1Yr ADP AMD Ryzen 5 Quad Core 7520U - (16 GB/512 GB SSD/Windows 11 Home) 15...',
#  'Lenovo Yoga Slim 7 Ultra 9 185H WUXGA OLED with 1Yr ADP Intel Core Ultra 9 185H - (32 GB/1 TB SSD/Wind...',
#  'MOTOROLA Motobook 60 Pro Full Metal OLED AI PC Intel Core Ultra 5 225H - (16 GB/512 GB SSD/Windows 11 ...',
#  'ASUS ExpertBook Ultra Copilot+ PC Intel Core Ultra X7 358H - (64 GB/2 TB SSD/Windows 11 Home) B9406CAA...',
#  'HP Intel Core i7 13th Gen 13620H - (16 GB/512 GB SSD/Windows 11 Home) 15-fr0046TU Thin and Light Lapto...',
#  'HP Intel Celeron Dual Core N4500 - (8 GB/512 GB SSD/Windows 11 Home) 14s-dq3149TU / 14s-dq3141TU Thin ...',
#  'ASUS Vivobook 15 (2025) with Office 2024 + M365 Basic*, Intel Core i3 13th Gen 1315U - (8 GB/512 GB SS...',
#  'HP Pavilion Plus Metal Body Intel Core i5 13th Gen 1335U - (16 GB/512 GB SSD/Windows 11 Home) 14-EW010...',
#  'MICROSOFT Surface Pro 12" with Type Cover Core 8 Snapdragon X Plus - (16 GB/256 GB SSD/Windows 11 Home...',
#  'ASUS ExpertBook P3 Intel Core Ultra 5 225H - (16 GB/512 GB SSD/Windows 11 Home) P3406CCAP-LY1005WS Lap...',
#  'Lenovo IdeaPad Slim 3 with 1Yr ADP Intel Core i5 12th Gen 12450H - (16 GB/512 GB SSD/Windows 11 Home) ...',
#  'Lenovo IdeaPad Slim 5 WUXGA OLED Full Metal Body with 1Yr ADP Intel Core i5 13th Gen 13420H - (16 GB/5...',
#  'MICROSOFT Surface Laptop 13" Snapdragon X Plus - (16 GB/512 GB SSD/Windows 11 Home) EP2-31940 Laptop',
#  'ASUS ExpertBook P3 Intel Core Ultra 7 255H - (16 GB/512 GB SSD/Windows 11 Home) P3606CCAP-MB1007WS Thi...',
#  'Acer Aspire 3 Intel Pentium Quad Core N4500 - (12 GB/512 GB SSD/Windows 11 Home) A325-45 Thin and Ligh...',
#  'HP 15 (i3 14th Gen) Intel Core 3 100U - (16 GB/512 GB SSD/Windows 11 Home) 15-fd0885TU Thin and Light ...',
#  "Lenovo IdeaPad Slim 3 Backlit Keyboard with MSO'2024 Intel Core i5 13th Gen 13420H - (24 GB/1 TB SSD/W...",
#  'ASUS Vivobook Go 14 (2025) with Office 2024 + M365 Basic* AMD Ryzen 3 Quad Core 7320U - (8 GB/512 GB S...',
#  'MICROSOFT Surface Pro 12" with Type Cover & Pen Core 8 Snapdragon X Plus - (16 GB/256 GB SSD/Windows 1...',
#  'MICROSOFT Surface Pro 12" with Pen Core 8 Snapdragon X Plus - (16 GB/512 GB SSD/Windows 11 Home) EP2-2...',
#  'Lenovo Chromebook MediaTek Kompanio 520 - (8 GB/128 GB EMMC Storage/Chrome OS) 14M868 Thin and Light L...',
#  'ASUS Vivobook 15 (2025) (i5 14th Gen) with MSO 2024 + M365 Basic*, Backlit Keyboard, Intel Core 5 120U...',
#  'MOTOROLA Motobook 60 Pro Full Metal OLED AI PC Intel Core Ultra 5 225H - (16 GB/512 GB SSD/Windows 11 ...',
#  'MOTOROLA Motobook 60 Pro Full Metal OLED AI PC Intel Core Ultra 5 225H - (16 GB/512 GB SSD/Windows 11 ...',
#  'Ultimus Apex Pro Intel Pentium Quad Core - (4 GB/128 GB SSD/128 GB EMMC Storage/Windows 11 Home) NU14U...',
#  'HP 15s Metal Intel Core i3 13th Gen 1315U - (8 GB/512 GB SSD/Windows 11 Home) 15-hr0005TU Thin and Lig...',
#  'ASUS Expertbook P3 Metal High-performance processor with 1 Yr ADP Intel Core i5 13th Gen 13420H - (16 ...',
#  'Acer Aspire Intel Celeron Dual Core N4500 - (12 GB/256 GB SSD/Windows 11 Home) A324-45-V2 Thin and Lig...',
#  'ASUS ExpertBook Ultra Copilot+ PC Intel Core Ultra X7 358H - (64 GB/2 TB SSD/Windows 11 Home) B9406CAA...',
#  'MICROSOFT Surface Pro 12" with Type Cover Core 8 Snapdragon X Plus - (16 GB/256 GB SSD/Windows 11 Home...',
#  'ASUS Vivobook 15 (2025) with Touchscreen & Backlit Keyboard, Intel Core i3 13th Gen 1315U - (8 GB/512 ...',
#  'Ultimus APEX BOLD N Intel Pentium Quad Core N4200 - (8 GB/256 GB SSD/Windows 11 Home) NU14U9INC54LS-CS...',
#  'ASUS ExpertBook P3 Intel Core Ultra 5 225H - (16 GB/512 GB SSD/Windows 11 Home) P3406CCAP-LY1005WS Lap...',
#  'MICROSOFT Surface Laptop 13" Snapdragon X Plus - (16 GB/512 GB SSD/Windows 11 Home) EP2-31940 Laptop',
#  'Ultimus Pro Intel Dual Core N4020 - (4 GB/128 GB EMMC Storage/Windows 11 Home) NU14U3CNC43BN-MB Thin a...',
#  'Lenovo IdeaPad Slim 5 WUXGA OLED Full metal with 1Yr ADP Intel Core i7 13th Gen 13620H - (16 GB/512 GB...',
#  'Acer Swift Neo Office 2024 + M365 Basic Intel Core Ultra 7 155U - (16 GB/512 GB SSD/Windows 11 Home) S...',
#  'DELL Inspiron 15 (Core i3 14th Gen) Intel Core 3 100U - (8 GB/512 GB SSD/Windows 11 Home) DC15250 Thin...',
#  'ASUS ExpertBook P3 Intel Core Ultra 7 255H - (16 GB/512 GB SSD/Windows 11 Home) P3606CCAP-MB1007WS Thi...',
#  'Samsung Galaxy Book4 Edge Series Copilot AI-PC Full Metal Chasis Snapdragon X - (16 GB/512 GB SSD/Wind...']
